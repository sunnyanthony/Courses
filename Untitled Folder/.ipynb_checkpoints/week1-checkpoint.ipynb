# %%
MSGS = [
    "",
    "234c02ecbbfbafa3ed18510abd11fa724fcda2018a1a8342cf064bbde548b12b07df44ba7191d9606ef4081ffde5ad46a5069d9f7f543bedb9c861bf29c7e205132eda9382b0bc2c5c4b45f919cf3a9f1cb74151f6d551f4480c82b2cb24cc5b028aa76eb7b4ab24171ab3cdadb8356f",
    "32510ba9a7b2bba9b8005d43a304b5714cc0bb0c8a34884dd91304b8ad40b62b07df44ba6e9d8a2368e51d04e0e7b207b70b9b8261112bacb6c866a232dfe257527dc29398f5f3251a0d47e503c66e935de81230b59b7afb5f41afa8d661cb",
    "",
    "3f561ba9adb4b6ebec54424ba317b564418fac0dd35f8c08d31a1fe9e24fe56808c213f17c81d9607cee021dafe1e001b21ade877a5e68bea88d61b93ac5ee0d562e8e9582f5ef375f0a4ae20ed86e935de81230b59b73fb4302cd95d770c65b40aaa065f2a5e33a5a0bb5dcaba43722130f042f8ec85b7c2070",
    "",
    "",
    "315c4eeaa8b5f8bffd11155ea506b56041c6a00c8a08854dd21a4bbde54ce56801d943ba708b8a3574f40c00fff9e00fa1439fd0654327a3bfc860b92f89ee04132ecb9298f5fd2d5e4b45e40ecc3b9d59e9417df7c95bba410e9aa2ca24c5474da2f276baa3ac325918b2daada43d6712150441c2e04f6565517f317da9d3",
    "",
    "466d06ece998b7a2fb1d464fed2ced7641ddaa3cc31c9941cf110abbf409ed39598005b3399ccfafb61d0315fca0a314be138a9f32503bedac8067f03adbf3575c3b8edc9ba7f537530541ab0f9f3cd04ff50d66f1d559ba520e89a2cb2a83"
]
DE = ["32510ba9babebbbefd001547a810e67149caee11d945cd7fc81a05e9f85aac650e9052ba6a8cd8257bf14d13e6f0a803b54fde9e77472dbff89d71b57bddef121336cb85ccb8f3315f4b52e301d16e9f52f904"]

# %%
import sys

def strxor(a, b):     # xor two strings of different lengths
    if len(a) > len(b):
       return "".join([chr(ord(x) ^ ord(y)) for (x, y) in zip(a[:len(b)], b)])
       #return "".join([chr(x ^ y) for (x, y) in zip(a[:len(b)], b)])
       '''
        chr() return the string representing a character whose Unicode code point is the integer i.
        ord() Given a string representing one Unicode character, return an integer representing the Unicode code point of that character.
       '''
    else:
       return "".join([chr(ord(x) ^ ord(y)) for (x, y) in zip(a, b[:len(a)])])
       #return "".join([chr(x ^ y) for (x, y) in zip(a, b[:len(a)])])

def random(size=16):
    return open("/dev/urandom",encoding = "ISO-8859-1").read(size)

def encrypt(key, msg):
    c = strxor(key, msg)
    print
    #print (c.encode('hex'))
    #print(c.encode("ISO-8859-1"))
    #print (codecs.encode(c, "ISO-8859-1"))
    return c

def main():
    key = random(1024)
    ciphertexts = [(key, msg) for msg in MSGS]

# %%
#" " ascii = 0010 0000
a = "afdsfasdi"
b = "         "
print("a ^ b = ",strxor(b,a),"\n")
print("a ^ b ^ b = ",strxor(strxor(b,a),b))
# Out:
# a ^ b AFDSFASDI
#
# a ^ b ^ b afdsfasdi

# %%
m1 = " I am a boy"
m2 = "You are pig"
key = random(1024)
c1 = encrypt(key,m1)
c2 = encrypt(key,m2)
c1
c2
for i in encrypt(MSGS[6],MSGS[8]):
    print(i)
# Out:
# b'&\xcc\xec\x93O\xf1\x0b_C6\xc3'
# b'_\xea\xb9\xd2C\xa3\x0f_Q0\xdd'
# b'\x01\x05\x04\x08\x04T\x00[\x03\x01\x04P\x03\\\x03\x01\x03\x07\x04\x05\x05\t\x01U\x00\n\x05R\x07R\x05\t\x05\x00\x00\x00\x03T\x04Z\x07\r\x01\x0fZ\x00\x01\x01\x07\x00\x01V\x01S\x04\x0f\x03\x04\x01\x03\x00P\x01\x07\x00\x05\x07\x0c\x01\n\x07X\x01R\x00\x0f\x07\x03\x04\x05\x00\\\x04W\x05\x06\x05\x04\x04\x03\x00R\x00T\x00X\x03\r\x01U\x00\x05]\x08\x01P\x01\x0b\x04P\x00\x00[P\x00\x0e\x01R\x00\x00\x01\x0e\x07\x07\x04V\x00\x04\x04W\x00]\\\x06\x01\x0b\x00U\x04\x05\x03\x01\x00\x06\x01^\x04\x07\x04\x02\x03]\x01S\x00\x06\x04\x07]\x07\x00X\x00\x01\x01\x07\x01\x01\x00]Z\x04\x01V\x00\x01\x04\x07\x04\x02\x01P\x00\x00\x07\x08\x01Q\x00U\x05\x04\x00R\x04\x07\x07\x00\x01\x01\x00\x00\x00\x07\x00\x00\x04Q\x05\x05\x01\x05\x00P[[\x04\x06\x00\x00\x01W\x04\x05\x04Z\x01S\x00T\x01\x01\x00T\\\x00\x00_\x00\x0c\x01V\x01\x02\x04\x07\x05\x02\x00\x04\x03V[\x04Z\x04\x00R\x04\x05\x05\x00\x03\x07\x00\x00\x01\x05\x00\x00\x01\x06\x01\x0b\x03\x0f\x00\x00[\x0e\x03\x02\x04V\x00\x06\x04V[\x04\x01\x00\x03\x00\x01\x07\\\t\x01\x02\x00\x06\x01U\x03S\x00\x06\x00UQR'
#
#
#
#
#
# T
#
# [
#
#
#
# P
#
# \
#
#
#
#
#
#
#
#
#
# U
#
#
#
#
# R
#
# R
#
#
#
#
#
#
#
# T
#
# Z
#
#
#
#
# Z
#
#
#
#
#
#
# V
#
# S
#
#
#
#
#
#
#
# P
#
#
#
#
#
#
#
#
#
#
# X
#
# R
#
#
#
#
#
#
#
# \
#
# W
#
#
#
#
#
#
#
# R
#
# T
#
# X
#
#
#
# U
#
#
# ]
#
#
# P
#
#
#
# P
#
#
# [
# P
#
#
#
# R
#
#
#
#
#
#
#
# V
#
#
#
# W
#
# ]
# \
#
#
#
#
# U
#
#
#
#
#
#
#
# ^
#
#
#
#
#
# ]
#
# S
#
#
#
#
# ]
#
#
# X
#
#
#
#
#
#
#
# ]
# Z
#
#
# V
#
#
#
#
#
#
#
# P
#
#
#
#
#
# Q
#
# U
#
#
#
# R
#
#
#
#
#
#
#
#
#
#
#
#
#
# Q
#
#
#
#
#
# P
# [
# [
#
#
#
#
#
# W
#
#
#
# Z
#
# S
#
# T
#
#
#
# T
# \
#
#
# _
#
#
#
# V
#
#
#
#
#
#
#
#
#
# V
# [
#
# Z
#
#
# R
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [
#
#
#
#
# V
#
#
#
# V
# [
#
#
#
#
#
#
#
# \
#
#
#
#
#
#
# U
#
# S
#
#
#
# U
# Q
# R

# %%
ciphertexts = [encrypt(MSGS[7], msg) for msg in MSGS]

l = len(ciphertexts)

guess = [" "]*len(ciphertexts[7])
for m in range(l):
    ll = len(ciphertexts[m])
    #gu = []
    for i in range(ll):
        if(ciphertexts[m][i].isalpha()):
            #gu.append(ciphertexts[m][i])
            #guess.insert(i,ciphertexts[m][i])
            guess[i] = ciphertexts[m][i]
        #else:
            #gu.append(" ")
            #guess.remove(i)
            #guess.insert(i," ")
            #if(~guess[i].isalpha()):
            #guess[i] = " "
    #guess.append(gu)
guess
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /Users/anthony/anaconda/envs/py3.5/lib/python3.5/encodings/hex_codec.py in hex_decode(input, errors)
#      18     assert errors == 'strict'
# ---> 19     return (binascii.a2b_hex(input), len(input))
#      20
#
# Error: Odd-length string
#
# The above exception was the direct cause of the following exception:
#
# Error                                     Traceback (most recent call last)
# <ipython-input-104-3bd075bddacb> in <module>()
#      10     #gu = []
#      11     for i in range(ll):
# ---> 12         if(codecs.decode(ciphertexts[m][i], "hex").isalpha()):
#      13             #gu.append(ciphertexts[m][i])
#      14             #guess.insert(i,ciphertexts[m][i])
#
# Error: decoding with 'hex' codec failed (Error: Odd-length string)

# %%
import codecs
n6 = codecs.decode(MSGS[6],'hex')
crib ="There are two types of cyptography: one that allows the Government to use brute force to break the code, and one that requires the Government to use brute force to break you"
key = encrypt(n6,crib)
encrypt(key,codecs.decode(MSGS[9],'hex'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-97e7e705183b> in <module>()
#       2 n6 = codecs.decode(MSGS[6],'hex')
#       3 crib ="There are two types of cyptography: one that allows the Government to use brute force to break the code, and one that requires the Government to use brute force to break you"
# ----> 4 key = encrypt(n6,crib)
#       5 encrypt(key,codecs.decode(MSGS[9],'hex'))
#
# <ipython-input-12-9d1c9b6b9d11> in encrypt(key, msg)
#      17
#      18 def encrypt(key, msg):
# ---> 19     c = strxor(key, msg)
#      20     print
#      21     #print (c.encode('hex'))
#
# <ipython-input-12-9d1c9b6b9d11> in strxor(a, b)
#       4     if len(a) > len(b):
#       5        #return "".join([chr(ord(x) ^ ord(y)) for (x, y) in zip(a[:len(b)], b)])
# ----> 6        return "".join([chr(x ^ y) for (x, y) in zip(a[:len(b)], b)])
#       7        '''
#       8         chr() return the string representing a character whose Unicode code point is the integer i.
#
# <ipython-input-12-9d1c9b6b9d11> in <listcomp>(.0)
#       4     if len(a) > len(b):
#       5        #return "".join([chr(ord(x) ^ ord(y)) for (x, y) in zip(a[:len(b)], b)])
# ----> 6        return "".join([chr(x ^ y) for (x, y) in zip(a[:len(b)], b)])
#       7        '''
#       8         chr() return the string representing a character whose Unicode code point is the integer i.
#
# TypeError: unsupported operand type(s) for ^: 'int' and 'str'
